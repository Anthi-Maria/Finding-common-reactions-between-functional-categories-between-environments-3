# %%
import numpy as np
import pandas as pd
import cobra.test
import os

from os.path import join

from time import time


from cobra.flux_analysis import (
    single_gene_deletion, single_reaction_deletion, double_gene_deletion,
    double_reaction_deletion)

a = cobra.io.read_sbml_model("iEC1344_C.xml")
# Out:
# Academic license - for non-commercial use only - expires 2023-02-21
# Using license file /home/schwartzlab/gurobi.lic

# %%
df= pd.read_csv('diff_saturated M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('flat anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions saturated M9 media-flat anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions saturated M9 media-one feasible value reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions saturated M9 media-Ushaped_reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions saturated M9 media-monotonically decreasing and stable reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions saturated M9 media-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions saturated M9 media-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions saturated M9 media-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions saturated M9 media-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions saturated M9 media-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 1

# %%
df= pd.read_csv('flat M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions flat M9 media-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions flat M9 media-one feasible value reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions flat M9 media-Ushaped_reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions flat M9 media-monotonically decreasing and stable reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions flat M9 media-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions flat M9 media-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions flat M9 media-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions flat M9 media-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions flat M9 media-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 3

# %%
df= pd.read_csv('one feasible value reactions M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions one feasible value M9 media-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions one feasible value M9 media-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions one feasible value M9 media-Ushaped_reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions one feasible value M9 media-monotonically decreasing and stable reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions one feasible value M9 media-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions one feasible value M9 media-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions one feasible value M9 media-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions one feasible value M9 media-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions one feasible value M9 media-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 10

# %%
df= pd.read_csv('Ushaped_reactions M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions Ushaped M9 media-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions Ushaped M9 media-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions Ushaped M9 media-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions Ushaped M9 media-monotonically decreasing and stable reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions Ushaped M9 media-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions Ushaped M9 media-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions Ushaped M9 media-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions Ushaped M9 media-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions Ushaped M9 media-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 1

# %%
df= pd.read_csv('monotonically decreasing and stable reactions M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing and stable M9 media-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing and stable M9 media-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing and stable M9 media-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing and stable M9 media-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing and stable M9 media-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing and stable M9 media-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing and stable M9 media-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing and stable M9 media-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing and stable M9 media-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 4

# %%
df= pd.read_csv('monotonically decreasing only reactions M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing only M9 media-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing only M9 media-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing only M9 media-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing only M9 media-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing only M9 media-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing only M9 media-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing only M9 media-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing only M9 media-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing only M9 media-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 7

# %%
df= pd.read_csv('monotonically increasing only reactions M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing only M9 media-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing only M9 media-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing only M9 media-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing only M9 media-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing only M9 media-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing only M9 media-monotonically decreasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing only M9 media-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing only M9 media-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing only M9 media-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 17

# %%
df= pd.read_csv('monotonically increasing and stable reactions M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing and stable M9 media-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing and stable M9 media-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing and stable M9 media-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing and stable M9 media-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing and stable M9 media-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing and stable M9 media-monotonically decreasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing and stable M9 media-monotonically increasing only reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing and stable M9 media-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing and stable M9 media-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 2

# %%
df= pd.read_csv('increasing and decreasing and stable reactions M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing and stable M9 media-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing and stable M9 media-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing and stable M9 media-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing and stable M9 media-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing and stable M9 media-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing and stable M9 media-monotonically decreasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing and stable M9 media-monotonically increasing only reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing and stable M9 media-monotonically increasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing and stable M9 media-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 20

# %%
df= pd.read_csv('increasing and decreasing only reactions M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing only M9 media-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing only M9 media-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing only M9 media-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing only M9 media-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing only M9 media-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing only M9 media-monotonically decreasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing only M9 media-monotonically increasing only reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing only M9 media-monotonically increasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing only M9 media-increasing and decreasing and stable reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 8

# %%
# Out:
# 0

# %%
df= pd.read_csv('diff_saturated study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('flat anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions saturated study conditions-flat anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions saturated study conditions-one feasible value reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions saturated study conditions-Ushaped_reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions saturated study conditions-monotonically decreasing and stable reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions saturated study conditions-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions saturated study conditions-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions saturated study conditions-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions saturated study conditions-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions saturated study conditions-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('flat study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions flat study conditions-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions flat study conditions-one feasible value reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions flat study conditions-Ushaped_reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions flat study conditions-monotonically decreasing and stable reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions flat study conditions-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions flat study conditions-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions flat study conditions-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions flat study conditions-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions flat study conditions-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 1

# %%
df= pd.read_csv('one feasible value reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions one feasible value study conditions-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions one feasible value study conditions-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions one feasible value study conditions-Ushaped_reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions one feasible value study conditions-monotonically decreasing and stable reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions one feasible value study conditions-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions one feasible value study conditions-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions one feasible value study conditions-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions one feasible value study conditions-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions one feasible value study conditions-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 25

# %%
df= pd.read_csv('Ushaped_reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions Ushaped study conditions-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions Ushaped study conditions-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions Ushaped study conditions-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions Ushaped study conditions-monotonically decreasing and stable reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions Ushaped study conditions-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions Ushaped study conditions-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions Ushaped study conditions-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions Ushaped study conditions-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions Ushaped study conditions-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 1

# %%
df= pd.read_csv('monotonically decreasing and stable reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing and stable study conditions-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing and stable study conditions-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing and stable study conditions-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing and stable study conditions-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing and stable study conditions-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing and stable study conditions-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing and stable study conditions-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing and stable study conditions-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing and stable study conditions-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('monotonically decreasing only reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing only study conditions-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing only study conditions-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing only study conditions-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing only study conditions-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing only study conditions-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing only study conditions-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing only study conditions-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing only study conditions-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing only study conditions-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 7

# %%
df= pd.read_csv('monotonically increasing only reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing only study conditions-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing only study conditions-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing only study conditions-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing only study conditions-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing only study conditions-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing only study conditions-monotonically decreasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing only study conditions-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing only study conditions-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing only study conditions-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 14

# %%
df= pd.read_csv('monotonically increasing and stable reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing and stable study conditions-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing and stable study conditions-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing and stable study conditions-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing and stable study conditions-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing and stable study conditions-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing and stable study conditions-monotonically decreasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing and stable study conditions-monotonically increasing only reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing and stable study conditions-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing and stable study conditions-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 2

# %%
df= pd.read_csv('increasing and decreasing and stable reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing and stable study conditions-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing and stable study conditions-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing and stable study conditions-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing and stable study conditions-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing and stable study conditions-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing and stable study conditions-monotonically decreasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing and stable study conditions-monotonically increasing only reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing and stable study conditions-monotonically increasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing and stable study conditions-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 11

# %%
df= pd.read_csv('increasing and decreasing only reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing only study conditions-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing only study conditions-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing only study conditions-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing only study conditions-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing only study conditions-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing only study conditions-monotonically decreasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing only study conditions-monotonically increasing only reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing only study conditions-monotonically increasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing only study conditions-increasing and decreasing and stable reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 12

# %%
df= pd.read_csv('diff_saturated lactose.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('flat anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions saturated lactose-flat anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions saturated lactose-one feasible value reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions saturated lactose-Ushaped_reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions saturated lactose-monotonically decreasing and stable reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions saturated lactose-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions saturated lactose-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions saturated lactose-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions saturated lactose-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions saturated lactose-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('flat lactose.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions flat lactose-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions flat lactose-one feasible value reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions flat lactose-Ushaped_reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions flat lactose-monotonically decreasing and stable reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions flat lactose-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions flat lactose-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions flat lactose-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions flat lactose-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions flat lactose-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('one feasible value reactions lactose.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions one feasible value lactose-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions one feasible value lactose-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions one feasible value lactose-Ushaped_reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions one feasible value lactose-monotonically decreasing and stable reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions one feasible value lactose-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions one feasible value lactose-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions one feasible value lactose-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions one feasible value lactose-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions one feasible value lactose-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('Ushaped_reactions lactose.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions Ushaped lactose-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions Ushaped lactose-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions Ushaped lactose-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions Ushaped lactose-monotonically decreasing and stable reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions Ushaped lactose-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions Ushaped lactose-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions Ushaped lactose-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions Ushaped lactose-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions Ushaped lactose-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 3

# %%
df= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing and stable lactose-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing and stable lactose-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing and stable lactose-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing and stable lactose-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing and stable lactose-monotonically decreasing only reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing and stable lactose-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing and stable lactose-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing and stable lactose-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing and stable lactose-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 6

# %%
df= pd.read_csv('monotonically decreasing only reactions lactose.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing only lactose-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing only lactose-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing only lactose-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing only lactose-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing only lactose-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing only lactose-monotonically increasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing only lactose-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing only lactose-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing only lactose-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 8

# %%
df= pd.read_csv('monotonically increasing only reactions lactose.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing only lactose-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing only lactose-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing only lactose-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing only lactose-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing only lactose-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing only lactose-monotonically decreasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing only lactose-monotonically increasing and stable reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing only lactose-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing only lactose-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 10

# %%
df= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing and stable lactose-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing and stable lactose-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing and stable lactose-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing and stable lactose-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing and stable lactose-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing and stable lactose-monotonically decreasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing and stable lactose-monotonically increasing only reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing and stable lactose-increasing and decreasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing and stable lactose-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 2

# %%
df= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing and stable lactose-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing and stable lactose-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing and stable lactose-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing and stable lactose-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing and stable lactose-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing and stable lactose-monotonically decreasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing and stable lactose-monotonically increasing only reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing and stable lactose-monotonically increasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing and stable lactose-increasing and decreasing only reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 29

# %%
df= pd.read_csv('increasing and decreasing only reactions lactose.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated anaerobic.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat anaerobic.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions anaerobic.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions anaerobic.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions anaerobic.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions anaerobic.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions anaerobic.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('monotonically increasing and stable reactions anaerobic.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing and stable reactions anaerobic.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing only lactose-saturated anaerobic")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing only lactose-flat reactions anaerobic")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing only lactose-one feasible value reactions anaerobic")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing only lactose-Ushaped reactions anaerobic")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing only lactose-monotonically decreasing and stable reactions anaerobic")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing only lactose-monotonically decreasing only reactions anaerobic")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing only lactose-monotonically increasing only reactions anaerobic")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing only lactose-monotonically increasing and stable reactions anaerobic")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing only lactose-increasing and decreasing and stable reactions anaerobic")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 9

# %%
# Out:
# 0

# %%
df= pd.read_csv('diff_saturated M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('flat lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions saturated M9 media-flat lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions saturated M9 media-one feasible value reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions saturated M9 media-Ushaped_reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions saturated M9 media-monotonically decreasing and stable reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions saturated M9 media-monotonically decreasing only reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions saturated M9 media-monotonically increasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions saturated M9 media-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions saturated M9 media-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions saturated M9 media-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 1

# %%
df= pd.read_csv('flat M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions flat M9 media-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions flat M9 media-one feasible value reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions flat M9 media-Ushaped_reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions flat M9 media-monotonically decreasing and stable reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions flat M9 media-monotonically decreasing only reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions flat M9 media-monotonically increasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions flat M9 media-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions flat M9 media-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions flat M9 media-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 1

# %%
df= pd.read_csv('one feasible value reactions M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions one feasible value M9 media-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions one feasible value M9 media-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions one feasible value M9 media-Ushaped_reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions one feasible value M9 media-monotonically decreasing and stable reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions one feasible value M9 media-monotonically decreasing only reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions one feasible value M9 media-monotonically increasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions one feasible value M9 media-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions one feasible value M9 media-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions one feasible value M9 media-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 97

# %%
df= pd.read_csv('Ushaped_reactions M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions Ushaped M9 media-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions Ushaped M9 media-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions Ushaped M9 media-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions Ushaped M9 media-monotonically decreasing and stable reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions Ushaped M9 media-monotonically decreasing only reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions Ushaped M9 media-monotonically increasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions Ushaped M9 media-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions Ushaped M9 media-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions Ushaped M9 media-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 1

# %%
df= pd.read_csv('monotonically decreasing and stable reactions M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing and stable M9 media-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing and stable M9 media-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing and stable M9 media-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing and stable M9 media-Ushaped reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing and stable M9 media-monotonically decreasing only reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing and stable M9 media-monotonically increasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing and stable M9 media-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing and stable M9 media-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing and stable M9 media-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 4

# %%
df= pd.read_csv('monotonically decreasing only reactions M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing only M9 media-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing only M9 media-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing only M9 media-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing only M9 media-Ushaped reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing only M9 media-monotonically decreasing and stable reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing only M9 media-monotonically increasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing only M9 media-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing only M9 media-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing only M9 media-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 44

# %%
df= pd.read_csv('monotonically increasing only reactions M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing only M9 media-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing only M9 media-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing only M9 media-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing only M9 media-Ushaped reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing only M9 media-monotonically decreasing and stable reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing only M9 media-monotonically decreasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing only M9 media-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing only M9 media-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing only M9 media-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 101

# %%
df= pd.read_csv('monotonically increasing and stable reactions M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing and stable M9 media-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing and stable M9 media-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing and stable M9 media-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing and stable M9 media-Ushaped reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing and stable M9 media-monotonically decreasing and stable reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing and stable M9 media-monotonically decreasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing and stable M9 media-monotonically increasing only reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing and stable M9 media-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing and stable M9 media-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('increasing and decreasing only reactions M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing only M9 media-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing only M9 media-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing only M9 media-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing only M9 media-Ushaped reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing only M9 media-monotonically decreasing and stable reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing only M9 media-monotonically decreasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing only M9 media-monotonically increasing only reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing only M9 media-monotonically increasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing only M9 media-increasing and decreasing and stable reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 30

# %%
df= pd.read_csv('increasing and decreasing and stable reactions M9 media.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing and stable M9 media-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing and stable M9 media-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing and stable M9 media-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing and stable M9 media-Ushaped reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing and stable M9 media-monotonically decreasing and stable reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing and stable M9 media-monotonically decreasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing and stable M9 media-monotonically increasing only reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing and stable M9 media-monotonically increasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing and stable M9 media-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 13

# %%
df= pd.read_csv('diff_saturated study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('flat lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions saturated study conditions-flat lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions saturated study conditions-one feasible value reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions saturated study conditions-Ushaped_reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions saturated study conditions-monotonically decreasing and stable reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions saturated study conditions-monotonically decreasing only reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions saturated study conditions-monotonically increasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions saturated study conditions-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions saturated study conditions-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions saturated study conditions-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('flat study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions flat study conditions-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions flat study conditions-one feasible value reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions flat study conditions-Ushaped_reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions flat study conditions-monotonically decreasing and stable reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions flat study conditions-monotonically decreasing only reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions flat study conditions-monotonically increasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions flat study conditions-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions flat study conditions-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions flat study conditions-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 6

# %%
df= pd.read_csv('one feasible value reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions one feasible value study conditions-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions one feasible value study conditions-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions one feasible value study conditions-Ushaped_reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions one feasible value study conditions-monotonically decreasing and stable reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions one feasible value study conditions-monotonically decreasing only reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions one feasible value study conditions-monotonically increasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions one feasible value study conditions-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions one feasible value study conditions-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions one feasible value study conditions-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 125

# %%
df= pd.read_csv('Ushaped_reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions Ushaped study conditions-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions Ushaped study conditions-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions Ushaped study conditions-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions Ushaped study conditions-monotonically decreasing and stable reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions Ushaped study conditions-monotonically decreasing only reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions Ushaped study conditions-monotonically increasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions Ushaped study conditions-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions Ushaped study conditions-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions Ushaped study conditions-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 1

# %%
df= pd.read_csv('monotonically decreasing and stable reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing and stable study conditions-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing and stable study conditions-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing and stable study conditions-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing and stable study conditions-Ushaped reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing and stable study conditions-monotonically decreasing only reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing and stable study conditions-monotonically increasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing and stable study conditions-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing and stable study conditions-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing and stable study conditions-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('monotonically decreasing only reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing only study conditions-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing only study conditions-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing only study conditions-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing only study conditions-Ushaped reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing only study conditions-monotonically decreasing and stable reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing only study conditions-monotonically increasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing only study conditions-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing only study conditions-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing only study conditions-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 54

# %%
df= pd.read_csv('monotonically increasing only reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing only study conditions-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing only study conditions-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing only study conditions-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing only study conditions-Ushaped reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing only study conditions-monotonically decreasing and stable reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing only study conditions-monotonically decreasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing only study conditions-monotonically increasing and stable reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing only study conditions-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing only study conditions-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 86

# %%
df= pd.read_csv('monotonically increasing and stable reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing and stable study conditions-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing and stable study conditions-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing and stable study conditions-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing and stable study conditions-Ushaped reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing and stable study conditions-monotonically decreasing and stable reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing and stable study conditions-monotonically decreasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing and stable study conditions-monotonically increasing only reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing and stable study conditions-increasing and decreasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing and stable study conditions-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('increasing and decreasing and stable reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing and stable study conditions-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing and stable study conditions-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing and stable study conditions-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing and stable study conditions-Ushaped reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing and stable study conditions-monotonically decreasing and stable reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing and stable study conditions-monotonically decreasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing and stable study conditions-monotonically increasing only reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing and stable study conditions-monotonically increasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing and stable study conditions-increasing and decreasing only reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 7

# %%
df= pd.read_csv('increasing and decreasing only reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated lactose.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat lactose.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions lactose.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions lactose.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions lactose.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions lactose.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions lactose.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('monotonically increasing and stable reactions lactose.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing and stable reactions lactose.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing only study conditions-saturated lactose")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing only study conditions-flat reactions lactose")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing only study conditions-one feasible value reactions lactose")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing only study conditions-Ushaped reactions lactose")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing only study conditions-monotonically decreasing and stable reactions lactose")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing only study conditions-monotonically decreasing only reactions lactose")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing only study conditions-monotonically increasing only reactions lactose")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing only study conditions-monotonically increasing and stable reactions lactose")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing only study conditions-increasing and decreasing and stable reactions lactose")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 31

# %%
df= pd.read_csv('diff_saturated study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('flat M9 media.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions M9 media.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions M9 media.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions M9 media.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions M9 media.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions M9 media.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions M9 media.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions M9 media.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions saturated study conditions-flat M9 media")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions saturated study conditions-one feasible value reactions M9 media")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions saturated study conditions-Ushaped_reactions M9 media")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions saturated study conditions-monotonically decreasing and stable reactions M9 media")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions saturated study conditions-monotonically decreasing only reactions M9 media")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions saturated study conditions-monotonically increasing only reactions M9 media")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions saturated study conditions-monotonically increasing and stable reactions M9 media")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions saturated study conditions-increasing and decreasing and stable reactions M9 media")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions saturated study conditions-increasing and decreasing only reactions M9 media")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('flat study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated M9 media.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('one feasible value reactions M9 media.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions M9 media.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions M9 media.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions M9 media.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions M9 media.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions M9 media.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions M9 media.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions flat study conditions-saturated M9 media")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions flat study conditions-one feasible value reactions M9 media")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions flat study conditions-Ushaped_reactions M9 media")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions flat study conditions-monotonically decreasing and stable reactions M9 media")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions flat study conditions-monotonically decreasing only reactions M9 media")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions flat study conditions-monotonically increasing only reactions M9 media")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions flat study conditions-monotonically increasing and stable reactions M9 media")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions flat study conditions-increasing and decreasing and stable reactions M9 media")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions flat study conditions-increasing and decreasing only reactions M9 media")

len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 1

# %%
df= pd.read_csv('one feasible value reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated M9 media.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat M9 media.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('Ushaped_reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions M9 media.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions M9 media.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions M9 media.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions M9 media.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions M9 media.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions M9 media.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions one feasible value study conditions-saturated M9 media")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions one feasible value study conditions-flat reactions M9 media")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions one feasible value study conditions-Ushaped_reactions M9 media")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions one feasible value study conditions-monotonically decreasing and stable reactions M9 media")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions one feasible value study conditions-monotonically decreasing only reactions M9 media")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions one feasible value study conditions-monotonically increasing only reactions M9 media")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions one feasible value study conditions-monotonically increasing and stable reactions M9 media")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions one feasible value study conditions-increasing and decreasing and stable reactions M9 media")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions one feasible value study conditions-increasing and decreasing only reactions M9 media")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 15

# %%
df= pd.read_csv('Ushaped_reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated M9 media.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat M9 media.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('monotonically decreasing and stable reactions M9 media.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions M9 media.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions M9 media.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions M9 media.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions M9 media.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions M9 media.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions Ushaped study conditions-saturated M9 media")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions Ushaped study conditions-flat reactions M9 media")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions Ushaped study conditions-one feasible value reactions M9 media")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions Ushaped study conditions-monotonically decreasing and stable reactions M9 media")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions Ushaped study conditions-monotonically decreasing only reactions M9 media")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions Ushaped study conditions-monotonically increasing only reactions M9 media")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions Ushaped study conditions-monotonically increasing and stable reactions M9 media")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions Ushaped study conditions-increasing and decreasing and stable reactions M9 media")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions Ushaped study conditions-increasing and decreasing only reactions M9 media")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('monotonically decreasing and stable reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated M9 media.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat M9 media.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions M9 media.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing only reactions M9 media.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions M9 media.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions M9 media.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions M9 media.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions M9 media.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing and stable study conditions-saturated M9 media")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing and stable study conditions-flat reactions M9 media")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing and stable study conditions-one feasible value reactions M9 media")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing and stable study conditions-Ushaped reactions M9 media")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing and stable study conditions-monotonically decreasing only reactions M9 media")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing and stable study conditions-monotonically increasing only reactions M9 media")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing and stable study conditions-monotonically increasing and stable reactions M9 media")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing and stable study conditions-increasing and decreasing and stable reactions M9 media")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing and stable study conditions-increasing and decreasing only reactions M9 media")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 1

# %%
df= pd.read_csv('monotonically decreasing only reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated M9 media.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat M9 media.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions M9 media.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions M9 media.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically increasing only reactions M9 media.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions M9 media.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions M9 media.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions M9 media.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically decreasing only study conditions-saturated M9 media")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically decreasing only study conditions-flat reactions M9 media")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically decreasing only study conditions-one feasible value reactions M9 media")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically decreasing only study conditions-Ushaped reactions M9 media")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically decreasing only study conditions-monotonically decreasing and stable reactions M9 media")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically decreasing only study conditions-monotonically increasing only reactions M9 media")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically decreasing only study conditions-monotonically increasing and stable reactions M9 media")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically decreasing only study conditions-increasing and decreasing and stable reactions M9 media")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically decreasing only study conditions-increasing and decreasing only reactions M9 media")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 11

# %%
df= pd.read_csv('monotonically increasing only reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated M9 media.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat M9 media.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions M9 media.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions M9 media.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions M9 media.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing and stable reactions M9 media.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions M9 media.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions M9 media.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing only study conditions-saturated M9 media")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing only study conditions-flat reactions M9 media")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing only study conditions-one feasible value reactions M9 media")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing only study conditions-Ushaped reactions M9 media")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing only study conditions-monotonically decreasing and stable reactions M9 media")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing only study conditions-monotonically decreasing only reactions M9 media")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing only study conditions-monotonically increasing and stable reactions M9 media")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing only study conditions-increasing and decreasing and stable reactions M9 media")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing only study conditions-increasing and decreasing only reactions M9 media")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 10

# %%
df= pd.read_csv('monotonically increasing and stable reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated M9 media.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat M9 media.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions M9 media.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions M9 media.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions M9 media.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions M9 media.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('increasing and decreasing and stable reactions M9 media.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions M9 media.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions monotonically increasing and stable study conditions-saturated M9 media")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions monotonically increasing and stable study conditions-flat reactions M9 media")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions monotonically increasing and stable study conditions-one feasible value reactions M9 media")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions monotonically increasing and stable study conditions-Ushaped reactions M9 media")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions monotonically increasing and stable study conditions-monotonically decreasing and stable reactions M9 media")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions monotonically increasing and stable study conditions-monotonically decreasing only reactions M9 media")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions monotonically increasing and stable study conditions-monotonically increasing only reactions M9 media")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions monotonically increasing and stable study conditions-increasing and decreasing and stable reactions M9 media")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions monotonically increasing and stable study conditions-increasing and decreasing only reactions M9 media")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 0

# %%
df= pd.read_csv('increasing and decreasing and stable reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated M9 media.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat M9 media.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions M9 media.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions M9 media.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions M9 media.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions M9 media.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('monotonically increasing and stable reactions M9 media.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing only reactions M9 media.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing and stable study conditions-saturated M9 media")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing and stable study conditions-flat reactions M9 media")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing and stable study conditions-one feasible value reactions M9 media")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing and stable study conditions-Ushaped reactions M9 media")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing and stable study conditions-monotonically decreasing and stable reactions M9 media")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing and stable study conditions-monotonically decreasing only reactions M9 media")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing and stable study conditions-monotonically increasing only reactions M9 media")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing and stable study conditions-monotonically increasing and stable reactions M9 media")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing and stable study conditions-increasing and decreasing only reactions M9 media")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 7

# %%
df= pd.read_csv('increasing and decreasing only reactions study conditions.csv')
b= df.iloc[:, 1]
df1= pd.read_csv('diff_saturated M9 media.csv')
c= df1.iloc[:, 1]
df2= pd.read_csv('flat M9 media.csv')
d= df2.iloc[:, 1]
df3= pd.read_csv('one feasible value reactions M9 media.csv')
e= df3.iloc[:, 1]
df4= pd.read_csv('Ushaped_reactions M9 media.csv')
f= df4.iloc[:, 1]
df5= pd.read_csv('monotonically decreasing and stable reactions M9 media.csv')
g= df5.iloc[:, 1]
df6= pd.read_csv('monotonically decreasing only reactions M9 media.csv')
h= df6.iloc[:, 1]
df7= pd.read_csv('monotonically increasing only reactions M9 media.csv')
i= df7.iloc[:, 1]
df8= pd.read_csv('monotonically increasing and stable reactions M9 media.csv')
j= df8.iloc[:, 1]
df9= pd.read_csv('increasing and decreasing and stable reactions M9 media.csv')
k= df9.iloc[:, 1]

intersect1 = pd.Series(np.intersect1d(b, c))
intersect2 = pd.Series(np.intersect1d(b, d))
intersect3 = pd.Series(np.intersect1d(b, e))
intersect4 = pd.Series(np.intersect1d(b, f))
intersect5 = pd.Series(np.intersect1d(b, g))
intersect6 = pd.Series(np.intersect1d(b, h))
intersect7 = pd.Series(np.intersect1d(b, i))
intersect8 = pd.Series(np.intersect1d(b, j))
intersect9 = pd.Series(np.intersect1d(b, k))

D= pd.DataFrame(intersect1, columns=['Reaction names'])
D.to_csv("Common reactions increasing and decreasing only study conditions-saturated M9 media")
D1= pd.DataFrame(intersect2, columns=['Reaction names'])
D1.to_csv("Common reactions increasing and decreasing only study conditions-flat reactions M9 media")
D2= pd.DataFrame(intersect3, columns=['Reaction names'])
D2.to_csv("Common reactions increasing and decreasing only study conditions-one feasible value reactions M9 media")
D3= pd.DataFrame(intersect4, columns=['Reaction names'])
D3.to_csv("Common reactions increasing and decreasing only study conditions-Ushaped reactions M9 media")
D4= pd.DataFrame(intersect5, columns=['Reaction names'])
D4.to_csv("Common reactions increasing and decreasing only study conditions-monotonically decreasing and stable reactions M9 media")
D5= pd.DataFrame(intersect6, columns=['Reaction names'])
D5.to_csv("Common reactions increasing and decreasing only study conditions-monotonically decreasing only reactions M9 media")
D6= pd.DataFrame(intersect7, columns=['Reaction names'])
D6.to_csv("Common reactions increasing and decreasing only study conditions-monotonically increasing only reactions M9 media")
D7= pd.DataFrame(intersect8, columns=['Reaction names'])
D7.to_csv("Common reactions increasing and decreasing only study conditions-monotonically increasing and stable reactions M9 media")
D8= pd.DataFrame(intersect9, columns=['Reaction names'])
D8.to_csv("Common reactions increasing and decreasing only study conditions-increasing and decreasing and stable reactions M9 media")


len(D)
len(D1)
len(D2)
len(D3)
len(D4)
len(D5)
len(D6)
len(D7)
len(D8)
# Out:
# 22

# %%
len(D)
# Out:
# 0
